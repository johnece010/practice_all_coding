# %%
Display="Hello_World"
print(Display)
# Out:
# Hello_World

# %%
Display = "John Prasanna Kumar"
print(Display)
# Out:
# John Prasanna Kumar

# %%
Display = "I am john,From Trichy"
print(Display)
# Out:
# I am john,From Trichy
